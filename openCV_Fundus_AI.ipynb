# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaJadhav/A-eye/blob/master/openCV_Fundus_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Different thresholding methods are explored in this notebook for 5 stages of Diabetic retinopathy images. The thresholding methods include- binary, tozero, adaptive, otsu and combination of methods for improving results.
#
# The combination of binary and otsu seems to give promising results.

# %% [markdown]
# #Binary thresholding

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(5):
  
    img = cv2.imread(str(i*9)+'.png',0)
    print("Diabetic retinopathy stage "+ str(i+1))
    ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
  
    titles = ['BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
    images = [thresh1, thresh2, thresh3, thresh4, thresh5]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()
# Out:
# Diabetic retinopathy stage 1
# Diabetic retinopathy stage 2
# Diabetic retinopathy stage 3
# Diabetic retinopathy stage 4
# Diabetic retinopathy stage 5

# %% [markdown]
# #Tozero thresholding

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(5):
  
    img = cv2.imread(str(i*9)+'.png',0)
    print("Diabetic retinopathy stage "+ str(i+1))
    ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
    ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
    ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
    titles = ['TRUNC','TOZERO','TOZERO_INV']
    images = [thresh3, thresh4, thresh5]

    for j in range(3):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()
# Out:
# Diabetic retinopathy stage 1
# Diabetic retinopathy stage 2
# Diabetic retinopathy stage 3
# Diabetic retinopathy stage 4
# Diabetic retinopathy stage 5

# %% [markdown]
# #Adaptive thresholding

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('0.png',0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()


import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(5):
  
    img = cv2.imread(str(i*9)+'.png',0)
    print("Diabetic retinopathy stage "+ str(i+1))
    ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    
    titles = ['Original Image', 'Global Thresholding (v = 127)']
    images = [img, th1, th2, th3]

    for i in range(2):
       plt.plot(2,2,i+1),plt.imshow(images[i],'gray')
       plt.title(titles[i])
       plt.xticks([]),plt.yticks([])
    plt.show()
# Out:
# Diabetic retinopathy stage 1
# Diabetic retinopathy stage 2
# Diabetic retinopathy stage 3
# Diabetic retinopathy stage 4
# Diabetic retinopathy stage 5

# %% [markdown]
# #Otsu thresholding

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(5):
  
    img = cv2.imread(str(i*8)+'.png',0)
    print("Diabetic retinopathy stage "+ str(i+1))
    
    ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# Otsu's thresholding after Gaussian filtering
    blur = cv2.GaussianBlur(img,(5,5),0)
    ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    titles = ['Binary','Binary+Otsu','Blur+binary+otsu']
    images = [th1, th2, th3]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()
# Out:
# Diabetic retinopathy stage 1
# Diabetic retinopathy stage 2
# Diabetic retinopathy stage 3
# Diabetic retinopathy stage 4
# Diabetic retinopathy stage 5

# %% [markdown]
# #Otsu and binary thresholding for DR 1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(10):
  
    img = cv2.imread(str(i)+'.png',0)
    
    ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_OTSU+cv2.THRESH_BINARY)

 
    titles = ['Binary','Otsu']
    images = [th1, th2]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()

# %% [markdown]
# #Otsu and binary thresholding for DR 2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(10,20):
  
    img = cv2.imread(str(i)+'.png',0)
    
    ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)

 
    titles = ['Binary','Otsu']
    images = [th1, th2]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()

# %% [markdown]
# #Otsu and binary thresholding for DR 3

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(20,30):
  
    img = cv2.imread(str(i)+'.png',0)
    
    ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)

 
    titles = ['Binary','Otsu']
    images = [th1, th2]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()

# %% [markdown]
# #Otsu and binary thresholding for DR 4

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(30,40):
  
    img = cv2.imread(str(i)+'.png',0)
    
    ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_OTSU)

 
    titles = ['Binary','Otsu']
    images = [th1, th2]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()

# %% [markdown]
# #Otsu and binary thresholding for DR 5

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


k=1
for i in range(40,50):
  
    img = cv2.imread(str(i)+'.png',0)
    
    ret1,th1 = cv2.threshold(img,50,255,cv2.THRESH_BINARY)

# Otsu's thresholding
    ret2,th2 = cv2.threshold(img,200,255,cv2.THRESH_OTSU)

 
    titles = ['Binary','Otsu']
    images = [th1, th2]

    for j in range(2):

       plt.imshow(images[j],'gray')
       plt.title(titles[j])
       k=k+1
       plt.show()

# %% [markdown]
# #Gamma correction

# %%
import cv2
import numpy as np


def gammaCorrection(gamma):
    linear = cv2.imread('3.png', 0)
    height = len(linear)
    width = len(linear[0])
    gamma_image = np.zeros((height, width))
    gamma_corrected_image = np.zeros((height, width))

    inv_gamma = 1 / gamma
    for i in range(height):
        for j in range(width):
            gamma_image[i][j] = 255 * ((linear[i][j] / 255) ** gamma)
            gamma_corrected_image[i][j] = 255 * ((linear[i][j] / 255) ** inv_gamma)
    cv2.imwrite('gamma_correction.png', gamma_corrected_image)
    cv2.imwrite('gamma_image.png', gamma_image)

def gammaImage():
    height = 900
    width = 1600
    checkerboard = np.ones((height, width)) * 255
    k = 0
    for i in range(0, height, 2):
        for j in range(0, width, 4):
            checkerboard[i][j + k] = 0
            checkerboard[i + 1][j + k] = 0
            checkerboard[i][j + k + 1] = 0
            checkerboard[i + 1][j + k + 1] = 0
        if k == 0:
            k = 2
        else:
            k = 0

    cv2.imwrite('checkerboard.png', checkerboard)
    Ic = (255 + 0) / 2

    g = 130
    gamma = 1.6
    uniform_gray = np.ones((height, width)) * g
    cv2.imwrite('uniform_gray.png', uniform_gray)

    interlaced = np.array(checkerboard)
    for i in range(0, height, 32):
        for j in range(0, width):
            for k in range(16):
                if i + k >= height:
                    break
                interlaced[i + k][j] = g
    Ig = 255 * ((g / 255) ** gamma)
    cv2.imwrite('interlaced.png', interlaced)
    return gamma
    #g = 138
    #gamma = 1.13
    #Ic = Ig = 127.5

if __name__ == '__main__':
    gammaCorrection(gammaImage())

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('gamma_correction.png',0)
    
img2=    cv2.imread('3.png', 0)
    
ret1,th1 = cv2.threshold(img,120,255,cv2.THRESH_BINARY) #dark pixels between 120-255
ret2,th2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV) # bright spots between 0-120
ret3,th3 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
imgcombined = th1+th2
plt.imshow(img2)
plt.show()
plt.imshow(th3,'gray')
plt.show()
plt.imshow(th2,'gray')
plt.show()
plt.imshow(imgcombined,'gray')
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('49.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

plt.imshow(img,'gray')
plt.show()
plt.imshow(thresh,'gray')
plt.show()

# %% [markdown]
# #Gamma correction and binary thresholding

# %%
import cv2
import numpy


import cv2
import numpy as np
from matplotlib import pyplot as plt

gamma = 1.6
k=1
for i in range(20,30):
  
    linear = cv2.imread(str(i)+'.png',0)
    
    height = len(linear)
    width = len(linear[0])
    gamma_image = np.zeros((height, width))
    gamma_corrected_image = np.zeros((height, width))

    inv_gamma = 1 / gamma
    for i in range(height):
      for j in range(width):
        gamma_image[i][j] = 255 * ((linear[i][j] / 255) ** gamma)
        gamma_corrected_image[i][j] = 255 * ((linear[i][j] / 255) ** inv_gamma)
    ret1,th1 = cv2.threshold(gamma_corrected_image,120,255,cv2.THRESH_BINARY) #dark pixels between 120-255
    ret2,th2 = cv2.threshold(gamma_corrected_image,160,255,cv2.THRESH_BINARY_INV) # bright spots between 0-120
    imgcombined = th2+th1
    plt.imshow(gamma_corrected_image,'gray') 
    plt.show()
   
    plt.imshow(imgcombined,'gray')
    plt.show()
